# %%
# %load_ext autoreload
# %autoreload 2
from misc import project_utils
from misc import project_utils_multi
import os
from IPython.display import HTML

folders = [ f.path for f in os.scandir('.') if f.is_dir()]
folders.remove('./.ipynb_checkpoints')
folders.remove('./files')
folders.sort()
for folder in folders:
    print('Model Folder: ', folder)
    history = project_utils.load_results(folder + '/history.txt')
    if 'is_multi' in history:
        print('Model is multi-output: True')
        project_utils_multi.plot_results(history)
    else:
        project_utils.plot_results(history)
    display(HTML('<br><hr><br>'))
# Out:
# Model Folder:  ./0001
# Number of Training:  753
# Number of Validation:  188
# Best IOU Training:  0.6211511492729187
# Best IOU Validation:  0.4422264099121094
# <h3>Layers</h3>
#   layer_type  units activation
# 0      Dense   1024       relu
# 1      Dense      5     linear
# <br><hr><br>
# Model Folder:  ./0002
# Number of Training:  991
# Number of Validation:  247
# Best IOU Training:  0.5144015550613403
# Best IOU Validation:  0.42489951848983765
# <h3>Layers</h3>
#   layer_type  units activation
# 0      Dense   1024       relu
# 1      Dense      5     linear
# <br><hr><br>
# Model Folder:  ./0003
# Number of Training:  2400
# Number of Validation:  599
# Best IOU Training:  0.48319947719573975
# Best IOU Validation:  0.30007296800613403
# <h3>Layers</h3>
#   layer_type  units activation
# 0      Dense   1024       relu
# 1      Dense      5     linear
# <br><hr><br>
# Model Folder:  ./0004
# Number of Training:  6400
# Number of Validation:  1599
# ...
